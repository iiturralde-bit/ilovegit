# %% [markdown]
# <a href="https://colab.research.google.com/github/iiturralde-bit/ilovegit/blob/main/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
x = 2+2
print(x)
# Out:
# 4
